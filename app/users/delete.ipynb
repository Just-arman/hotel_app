# %%
# pip install passlib python-jose

# %%
from passlib.context import CryptContext

pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

def get_password_hash(password: str) -> str:
    return pwd_context.hash(password)

def verify_password(plain_password, hashed_password) -> bool:
    return pwd_context.verify(plain_password, hashed_password)

# %%
get_password_hash("arman")
# Out:
# '$2b$12$vFpCNWPGYLG2Th.QxwBrFuhf6KdztQ/1na/6S.WAzP3Osw61ysJCm'

# %%
hashed_password = '$2b$12$vFpCNWPGYLG2Th.QxwBrFuhf6KdztQ/1na/6S.WAzP3Osw61ysJCm'
verify_password("arman", hashed_password)
# Out:
# True

# %%
from jose import jwt
from datetime import datetime, timedelta, timezone

def create_access_token(data: dict) -> str:
    to_encode = data.copy()
    expire = datetime.now(timezone.utc).replace(tzinfo=None) + timedelta(minutes=30)
    to_encode.update({"exp": expire})
    encoded_jwt = jwt.encode(
        to_encode, "dsfrdgdfgsdfasffesf", "HS256"
    )
    return encoded_jwt

# %%
create_access_token({"user": "arman"})
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyIjoiYXJtYW4iLCJleHAiOjE3NDk4ODc1MzR9.DALcRZh_OmPGGTmOK1uTxTgNWCUZnPs9fBHPrtVGJCQ'
